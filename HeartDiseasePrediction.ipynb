# %% [markdown]
# <a href="https://colab.research.google.com/github/peternjathi/matplotlib-projects/blob/main/HeartDiseasePrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
print("setup complete")
# Out:
# setup complete

# %%
data = pd.read_csv("heart_2020_cleaned.csv")
data.sample(10)
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 304959           No  26.61     Yes              No     No             0.0
# 47336            No  31.62     Yes              No    Yes             7.0
# 86910            No  24.33      No              No     No             0.0
# 139398           No  33.72      No              No     No            14.0
# 54593            No  28.41      No              No     No             2.0
# 103626           No  18.55      No              No     No             0.0
# 42188            No  36.05     Yes              No    Yes             0.0
# 75077            No  22.83     Yes              No     No             0.0
# 164906           No  26.39      No              No     No             0.0
# 154877           No  33.23      No             Yes     No            10.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 304959           0.0          No    Male        75-79  White
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
data.shape
# Out:
# (319795, 18)

# %% [markdown]
# shows number of colums and no of rows

# %%
data.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
data.PhysicalActivity.value_counts()
# Out:
# Yes    247957
# No      71838
# Name: PhysicalActivity, dtype: int64

# %%
data.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %% [markdown]
#  data.colimns ..   shows all columns that we have in our data set.

# %%
plt.figure(figsize=(10,3))
sns.barplot(data=data, x='HeartDisease', y='PhysicalHealth', hue='Diabetic')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='PhysicalHealth'>

# %%
plt.figure(figsize=(10,3))
sns.countplot(data=data, x='HeartDisease')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='count'>

# %% [markdown]
# sns.countplot(data=data, x='HeartDisease')    its compaires our data set with people tha has heart disease.

# %%
data.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
plt.gcf().set_size_inches((20,20))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,3))
sns.countplot(data=data, x='SleepTime')
# Out:
# <Axes: xlabel='SleepTime', ylabel='count'>

# %% [markdown]
# We check how long people with heart Disease sleep According to our dataset
